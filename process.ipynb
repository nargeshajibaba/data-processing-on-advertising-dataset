# %%
import pandas as pd

# %%
df = pd.read_csv("advertising.csv")
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
df.head(8)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
# 5                     59.99   23     59761.56                226.74
# 6                     88.91   33     53852.85                208.36
# 7                     66.00   48     24593.33                131.76
#
#                            Ad Topic Line              City  Male     Country  \
# 0     Cloned 5thgeneration orchestration       Wrightburgh     0     Tunisia
# 1     Monitored national standardization         West Jodi     1       Nauru
# 2       Organic bottom-line service-desk          Davidton     0  San Marino
# ...

# %%
df.head(2)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
#
#                         Ad Topic Line         City  Male  Country  \
# 0  Cloned 5thgeneration orchestration  Wrightburgh     0  Tunisia
# 1  Monitored national standardization    West Jodi     1    Nauru
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# 1  2016-04-04 01:39:02              0

# %%
df.tail()
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                             Ad Topic Line           City  Male  \
# 995         Fundamental modular algorithm      Duffystad     1
# 996       Grass-roots cohesive monitoring    New Darlene     1
# 997          Expanded intangible solution  South Jessica     1
# 998  Proactive bandwidth-monitored policy    West Steven     0
# 999       Virtual 5thgeneration emulation    Ronniemouth     0
#
#                     Country            Timestamp  Clicked on Ad
# 995                 Lebanon  2016-02-11 21:49:00              1
# ...

# %%
df.tail(8)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 992                     69.17   40     66193.81                123.62
# 993                     64.20   27     66200.96                227.63
# 994                     43.70   28     63126.96                173.01
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                             Ad Topic Line           City  Male  \
# 992         Extended leadingedge solution    New Patrick     0
# 993        Phased zero tolerance extranet   Edwardsmouth     1
# 994         Front-line bifurcated ability   Nicholasland     0
# 995         Fundamental modular algorithm      Duffystad     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
df["Ad Topic Line"]
# Out:
# 0         Cloned 5thgeneration orchestration
# 1         Monitored national standardization
# 2           Organic bottom-line service-desk
# 3      Triple-buffered reciprocal time-frame
# 4              Robust logistical utilization
#                        ...
# 995            Fundamental modular algorithm
# 996          Grass-roots cohesive monitoring
# 997             Expanded intangible solution
# 998     Proactive bandwidth-monitored policy
# 999          Virtual 5thgeneration emulation
# Name: Ad Topic Line, Length: 1000, dtype: object

# %%
df[["Ad Topic Line" , "Age" , "Area Income"]]
# Out:
#                              Ad Topic Line  Age  Area Income
# 0       Cloned 5thgeneration orchestration   35     61833.90
# 1       Monitored national standardization   31     68441.85
# 2         Organic bottom-line service-desk   26     59785.94
# 3    Triple-buffered reciprocal time-frame   29     54806.18
# 4            Robust logistical utilization   35     73889.99
# ..                                     ...  ...          ...
# 995          Fundamental modular algorithm   30     71384.57
# 996        Grass-roots cohesive monitoring   45     67782.17
# 997           Expanded intangible solution   51     42415.72
# 998   Proactive bandwidth-monitored policy   19     41920.79
# 999        Virtual 5thgeneration emulation   26     29875.80
#
# [1000 rows x 3 columns]

# %%
df["Age"].max()
# Out:
# np.int64(61)

# %%
df["Age"].mean()
# Out:
# np.float64(36.009)

# %%
df["Age"].min()
# Out:
# np.int64(19)

# %%
df.drop("Age" , axis=1)
# Out:
#      Daily Time Spent on Site  Area Income  Daily Internet Usage  \
# 0                       68.95     61833.90                256.09
# 1                       80.23     68441.85                193.77
# 2                       69.47     59785.94                236.50
# 3                       74.15     54806.18                245.89
# 4                       68.37     73889.99                225.58
# ..                        ...          ...                   ...
# 995                     72.97     71384.57                208.58
# 996                     51.30     67782.17                134.42
# 997                     51.63     42415.72                120.37
# 998                     55.55     41920.79                187.95
# 999                     45.01     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# 0       Cloned 5thgeneration orchestration     Wrightburgh     0
# ...

# %%
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
df = df.drop("Age" , axis=1)
df
# Out:
#      Daily Time Spent on Site  Area Income  Daily Internet Usage  \
# 0                       68.95     61833.90                256.09
# 1                       80.23     68441.85                193.77
# 2                       69.47     59785.94                236.50
# 3                       74.15     54806.18                245.89
# 4                       68.37     73889.99                225.58
# ..                        ...          ...                   ...
# 995                     72.97     71384.57                208.58
# 996                     51.30     67782.17                134.42
# 997                     51.63     42415.72                120.37
# 998                     55.55     41920.79                187.95
# 999                     45.01     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# 0       Cloned 5thgeneration orchestration     Wrightburgh     0
# ...

# %%
df.drop(["Area Income" , "Ad Topic Line" , "Male"] , axis=1)
# Out:
#      Daily Time Spent on Site  Daily Internet Usage            City  \
# 0                       68.95                256.09     Wrightburgh
# 1                       80.23                193.77       West Jodi
# 2                       69.47                236.50        Davidton
# 3                       74.15                245.89  West Terrifurt
# 4                       68.37                225.58    South Manuel
# ..                        ...                   ...             ...
# 995                     72.97                208.58       Duffystad
# 996                     51.30                134.42     New Darlene
# 997                     51.63                120.37   South Jessica
# 998                     55.55                187.95     West Steven
# 999                     45.01                178.35     Ronniemouth
#
#                     Country            Timestamp  Clicked on Ad
# 0                   Tunisia  2016-03-27 00:53:11              0
# ...

# %%
df.drop(0 , axis=0)
# Out:
#      Daily Time Spent on Site  Area Income  Daily Internet Usage  \
# 1                       80.23     68441.85                193.77
# 2                       69.47     59785.94                236.50
# 3                       74.15     54806.18                245.89
# 4                       68.37     73889.99                225.58
# 5                       59.99     59761.56                226.74
# ..                        ...          ...                   ...
# 995                     72.97     71384.57                208.58
# 996                     51.30     67782.17                134.42
# 997                     51.63     42415.72                120.37
# 998                     55.55     41920.79                187.95
# 999                     45.01     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# 1       Monitored national standardization       West Jodi     1
# ...

# %%
df.columns
# Out:
# Index(['Daily Time Spent on Site', 'Area Income', 'Daily Internet Usage',
#        'Ad Topic Line', 'City', 'Male', 'Country', 'Timestamp',
#        'Clicked on Ad'],
#       dtype='object')

# %%
df["Area Income 2"] = df["Area Income"]*2

# %%
df
# Out:
#      Daily Time Spent on Site  Area Income  Daily Internet Usage  \
# 0                       68.95     61833.90                256.09
# 1                       80.23     68441.85                193.77
# 2                       69.47     59785.94                236.50
# 3                       74.15     54806.18                245.89
# 4                       68.37     73889.99                225.58
# ..                        ...          ...                   ...
# 995                     72.97     71384.57                208.58
# 996                     51.30     67782.17                134.42
# 997                     51.63     42415.72                120.37
# 998                     55.55     41920.79                187.95
# 999                     45.01     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# 0       Cloned 5thgeneration orchestration     Wrightburgh     0
# ...

# %%
d = []
for i in df["Clicked on Ad"]:
    if i == 1:
        d.append("yes")
    elif i == 0:
        d.append("no")
df["Clicked on Ad y/n"] = d
df
# Out:
#      Daily Time Spent on Site  Area Income  Daily Internet Usage  \
# 0                       68.95     61833.90                256.09
# 1                       80.23     68441.85                193.77
# 2                       69.47     59785.94                236.50
# 3                       74.15     54806.18                245.89
# 4                       68.37     73889.99                225.58
# ..                        ...          ...                   ...
# 995                     72.97     71384.57                208.58
# 996                     51.30     67782.17                134.42
# 997                     51.63     42415.72                120.37
# 998                     55.55     41920.79                187.95
# 999                     45.01     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# 0       Cloned 5thgeneration orchestration     Wrightburgh     0
# ...
